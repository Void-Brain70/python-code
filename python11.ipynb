# %% [markdown]
# <a href="https://colab.research.google.com/github/Void-Brain70/Python/blob/master/python11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
height =[3,12,5,18,45]
bars=('A','B','C','D','E')
y_pos=np.arange(len(bars))
plt.bar(y_pos,height)
plt.xticks(y_pos,bars)
plt.show()

# %%
import matplotlib.pyplot as plt

from matplotlib_venn import venn3
venn3(subsets=(10,8,22,6,9,4,2))
plt.show()
