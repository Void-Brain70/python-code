# %% [markdown]
# <a href="https://colab.research.google.com/github/Void-Brain70/Python/blob/master/PIC_UP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from google.colab.patches import cv2_imshow

import cv2
img=cv2.imread("/content/python.jpg",0)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=601x608 at 0x7F0940C0D490>
